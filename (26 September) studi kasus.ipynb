# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Alam-A99/Case-Study/main/retail_raw.csv')
df.head(5)
# Out:
#    order_id  order_date  customer_id             city     province product_id  \
# 0   1703458  2019-10-17        14004  Jakarta Selatan  DKI Jakarta      P1910
# 1   1706815  2019-10-24        17220  Jakarta Selatan  DKI Jakarta      P2934
# 2   1710718  2019-11-03        16518    Jakarta Utara  DKI Jakarta      P0908
# 3   1683592  2019-08-19        16364    Jakarta Barat  DKI Jakarta      P0128
# 4   1702573  2019-10-16        15696    Jakarta Timur  DKI Jakarta      P2968
#
#      brand  quantity  item_price
# 0  BRAND_J        10      740000
# 1  BRAND_R         2      604000
# 2  BRAND_C         8     1045000
# 3  BRAND_A         4      205000
# 4  BRAND_R         2     4475000

# %%
import csv
import urllib3
url = 'https://raw.githubusercontent.com/Alam-A99/Case-Study/main/retail_raw.csv'
response = urllib2.urlopen(url)
cr = csv.reader(response)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Alam-A99/Case-Study/main/retail_raw.csv')
df.head(60)
# Out:
#     order_id  order_date  customer_id             city     province  \
# 0    1703458  2019-10-17        14004  Jakarta Selatan  DKI Jakarta
# 1    1706815  2019-10-24        17220  Jakarta Selatan  DKI Jakarta
# 2    1710718  2019-11-03        16518    Jakarta Utara  DKI Jakarta
# 3    1683592  2019-08-19        16364    Jakarta Barat  DKI Jakarta
# 4    1702573  2019-10-16        15696    Jakarta Timur  DKI Jakarta
# 5    1672906  2019-07-16        12748    Jakarta Utara  DKI Jakarta
# 6    1711399  2019-11-04        16791    Jakarta Barat  DKI Jakarta
# 7    1695367  2019-09-26        13069        Surakarta  Jawa Tengah
# 8    1741846  2019-12-30        16873    Jakarta Barat  DKI Jakarta
# 9    1720189  2019-11-24        14723        Tangerang       Banten
# 10   1683583  2019-08-19        13814         Denpasar         Bali
# 11   1693309  2019-09-19        17841    Jakarta Utara  DKI Jakarta
# 12   1708381  2019-10-29        13895        Tangerang       Banten
# ...

# %%
import pandas as pd
import numpy as np
import statistics
df = np.array([10, 2, 8, 4, 2])
DF = np.array([740000, 604000, 1045000, 205000, 4475000])
print("nilai dari quantity")
print("")
print("----------------------------")
print("Nilai minimal =", df.min())
print("")
print("-----------------------------")
print("Nilai maksimal =", df.max())
print("")
print("-----------------------------")
print("Nilai rata-rata =", df.mean())
print("")
print("-----------------------------")
print("Standar Deviasi =", df.std())
print("")
print("-----------------------------")
print("Jumlah =", df.sum())
print("")
print("-----------------------------")
print("Varians =", df.var())
print("")
print("------------------------------")
print("")
print("------------------------------")
print("nilai dari item price")
print("")
print("-------------------------------")
print("Nilai minimal =", DF.min())
print("")
print("-----------------------------")
print("Nilai maksimal =", DF.max())
print("")
print("-----------------------------")
print("Nilai rata-rata =", DF.mean())
print("")
print("-----------------------------")
print("Standar Deviasi =", DF.std())
print("")
print("-----------------------------")
print("Jumlah =", DF.sum())
print("")
print("-----------------------------")
print("Varians =", DF.var())
print("")
print("------------------------------")
print("")
print("------------------------------")
print("nilai dari quantity + item_price")
print("")
print("------------------------------")
print("Nilai minimal =", df*DF.min())
print("")
print("-----------------------------")
print("Nilai maksimal =", df*DF.max())
print("")
print("-----------------------------")
print("Nilai rata-rata =", df*DF.mean())
print("")
print("-----------------------------")
print("Standar Deviasi =", df*DF.std())
print("")
print("-----------------------------")
print("Jumlah =", df*DF.sum())
print("")
print("-----------------------------")
print("Varians =", df*DF.var())
print("")
print("------------------------------")
print("")
print("------------------------------")
# Out:
# nilai dari quantity
#
# ----------------------------
# Nilai minimal = 2
#
# -----------------------------
# Nilai maksimal = 10
#
# -----------------------------
# Nilai rata-rata = 5.2
#
# -----------------------------
# Standar Deviasi = 3.249615361854384
#
# -----------------------------
# Jumlah = 26
#
# -----------------------------
# Varians = 10.559999999999999
#
# ------------------------------
#
# ------------------------------
# nilai dari item price
#
# -------------------------------
# Nilai minimal = 205000
#
# -----------------------------
# Nilai maksimal = 4475000
#
# -----------------------------
# Nilai rata-rata = 1413800.0
#
# -----------------------------
# Standar Deviasi = 1554216.12396732
#
# -----------------------------
# Jumlah = 7069000
#
# -----------------------------
# Varians = 2415587760000.0
#
# ------------------------------
#
# ------------------------------
# nilai dari quantity + item_price
#
# ------------------------------
# ...

# %%
import matplotlib.pyplot as plt
from scipy import stats

A = [2, 5, 7, 8, 3, 9, 3, 5, 9, 11, 5, 2, 9]
B = [100, 99, 98, 97, 96, 95, 94, 93, 92, 91, 90, 89, 88]

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Alam-A99/Case-Study/main/car_speed.csv')
df.head(5)
# Out:
#   Carname  Color  Age  Speed AutoPass
# 0     BMW    red    5   99.0        Y
# 1     SMK  black    7   86.0        Y
# 2      VW   gray    8   87.0        N
# 3      VW  white    7   88.0        Y
# 4    Ford  white    2  111.0        Y

# %%
import pandas as pd
import numpy as np
import statistics
df = np.array([5, 7, 8, 7, 2 ])
DF = np.array([99.0, 86.0, 87.0, 88.0, 111.0])
print("nilai dari age")
print("")
print("----------------------------")
print("Nilai minimal =", df.min())
print("")
print("-----------------------------")
print("Nilai maksimal =", df.max())
print("")
print("-----------------------------")
print("Nilai rata-rata =", df.mean())
print("")
print("-----------------------------")
print("Standar Deviasi =", df.std())
print("")
print("-----------------------------")
print("Jumlah =", df.sum())
print("")
print("-----------------------------")
print("Varians =", df.var())
print("")
print("------------------------------")
print("")
print("------------------------------")
print("nilai dari speed")
print("")
print("-------------------------------")
print("Nilai minimal =", DF.min())
print("")
print("-----------------------------")
print("Nilai maksimal =", DF.max())
print("")
print("-----------------------------")
print("Nilai rata-rata =", DF.mean())
print("")
print("-----------------------------")
print("Standar Deviasi =", DF.std())
print("")
print("-----------------------------")
print("Jumlah =", DF.sum())
print("")
print("-----------------------------")
print("Varians =", DF.var())
print("")
print("------------------------------")
print("")
print("------------------------------")
print("nilai dari age + speed")
print("")
print("------------------------------")
print("Nilai minimal =", df*DF.min())
print("")
print("-----------------------------")
print("Nilai maksimal =", df*DF.max())
print("")
print("-----------------------------")
print("Nilai rata-rata =", df*DF.mean())
print("")
print("-----------------------------")
print("Standar Deviasi =", df*DF.std())
print("")
print("-----------------------------")
print("Jumlah =", df*DF.sum())
print("")
print("-----------------------------")
print("Varians =", df*DF.var())
print("")
print("------------------------------")
print("")
print("------------------------------")
# Out:
# nilai dari age
#
# ----------------------------
# Nilai minimal = 2
#
# -----------------------------
# Nilai maksimal = 8
#
# -----------------------------
# Nilai rata-rata = 5.8
#
# -----------------------------
# Standar Deviasi = 2.1354156504062622
#
# -----------------------------
# Jumlah = 29
#
# -----------------------------
# Varians = 4.5600000000000005
#
# ------------------------------
#
# ------------------------------
# nilai dari speed
#
# -------------------------------
# Nilai minimal = 86.0
#
# -----------------------------
# Nilai maksimal = 111.0
#
# -----------------------------
# Nilai rata-rata = 94.2
#
# -----------------------------
# Standar Deviasi = 9.620810776644554
#
# -----------------------------
# Jumlah = 471.0
#
# -----------------------------
# Varians = 92.55999999999999
#
# ------------------------------
#
# ------------------------------
# nilai dari age + speed
#
# ------------------------------
# Nilai minimal = [430. 602. 688. 602. 172.]
#
# ...

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


x= np.array([5, 7, 8, 7, 2])
y = x*2 + 3

sns.regplot(x=x, y=y)
plt.title('regresi age', color= 'yellow')
# Out:
# Text(0.5, 1.0, 'regresi age')

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt


x= np.array([99.0, 86.0, 87.0, 88.0, 111.0])
y = x*2 + 3

sns.regplot(x=x, y=y)
plt.title('regresi speed', color= 'yellow')
# Out:
# Text(0.5, 1.0, 'regresi speed')
